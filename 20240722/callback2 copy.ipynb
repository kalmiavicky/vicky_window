# %%
#如果執行有問題 VS 重開
from dash import Dash,html,dcc,Input,Output,callback
import pandas as pd

app = Dash(__name__)

df = pd.read_csv('https://plotly.github.io/datasets/country_indicators.csv')

# %%
display(df)
df['Indicator Name'].unique()
# Out:
#       Country Name                                     Indicator Name  Year  \
# 0       Arab World                Agriculture, value added (% of GDP)  1962
# 1       Arab World             CO2 emissions (metric tons per capita)  1962
# 2       Arab World  Domestic credit provided by financial sector (...  1962
# 3       Arab World        Electric power consumption (kWh per capita)  1962
# 4       Arab World       Energy use (kg of oil equivalent per capita)  1962
# ...            ...                                                ...   ...
# 36955     Zimbabwe                   Industry, value added (% of GDP)  2007
# 36956     Zimbabwe                 Inflation, GDP deflator (annual %)  2007
# 36957     Zimbabwe            Life expectancy at birth, total (years)  2007
# 36958     Zimbabwe  Population density (people per sq. km of land ...  2007
# 36959     Zimbabwe             Services, etc., value added (% of GDP)  2007
#
#            Value
# 0            NaN
# 1       0.760996
# 2      18.168690
# 3            NaN
# 4            NaN
# ...          ...
# 36955  33.074953
# 36956   0.894887
# 36957  44.177756
# 36958  34.374559
# 36959  45.327139
#
# [36960 rows x 4 columns]
# array(['Agriculture, value added (% of GDP)',
#        'CO2 emissions (metric tons per capita)',
#        'Domestic credit provided by financial sector (% of GDP)',
#        'Electric power consumption (kWh per capita)',
#        'Energy use (kg of oil equivalent per capita)',
#        'Exports of goods and services (% of GDP)',
#        'Fertility rate, total (births per woman)',
#        'GDP growth (annual %)',
#        'Imports of goods and services (% of GDP)',
#        'Industry, value added (% of GDP)',
#        'Inflation, GDP deflator (annual %)',
#        'Life expectancy at birth, total (years)',
#        'Population density (people per sq. km of land area)',
#        'Services, etc., value added (% of GDP)'], dtype=object)

# %%
app.layout = html.Div([
    html.Div([
        html.Div([
            dcc.Dropdown(
                df['Indicator Name'].unique(),
                'Fertility rate, total (births per woman)',
                id='xaxis-column'
            ),
            dcc.RadioItems(
                ['Linear','Log'],
                'Linear',
                id = 'xaxis-type',
                inline=True
            )
        ],style={'width':'48%','display':'inline-block'}),
        html.Div([
            dcc.Dropdown(
                df['Indicator Name'].unique(),
                'Life expectancy at birth, total (years)',
                id='yaxis-column'
            ),
            dcc.RadioItems(
                ['Linear','Log'],
                'Linear',
                id = 'yaxis-type',
                inline=True
            )
        ],style={'width':'48%','float':'right','display':'inline-block'})
    ]),
    dcc.Graph(id='indicator-graphic'),
    dcc.Slider(
        min=df['Year'].min(),
        max=df['Year'].max(),
        step=None,
        id='year--slider',
        value=df['Year'].max(),
        marks = {str(year):str(year) for year in df['Year'].unique()}
    )

])

if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 43
#       1 app.layout = html.Div([
#       2     html.Div([
#       3         html.Div([
#    (...)
#      39
#      40 ])
#      42 if __name__ == '__main__':
# ---> 43     app.run(debug=True)
#
# File c:\Users\win\miniconda3\envs\venv1\lib\site-packages\dash\dash.py:2099, in Dash.run(self, host, port, proxy, debug, jupyter_mode, jupyter_width, jupyter_height, jupyter_server_url, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2096 if debug is None:
#    2097     debug = get_combined_config("debug", None, False)
# -> 2099 debug = self.enable_dev_tools(
#    2100     debug,
#    2101     dev_tools_ui,
#    2102     dev_tools_props_check,
#    2103     dev_tools_serve_dev_bundles,
#    2104     dev_tools_hot_reload,
#    2105     dev_tools_hot_reload_interval,
#    2106     dev_tools_hot_reload_watch_interval,
#    2107     dev_tools_hot_reload_max_retry,
#    2108     dev_tools_silence_routes_logging,
#    2109     dev_tools_prune_errors,
#    2110 )
#    2112 # Verify port value
#    2113 try:
#
# File c:\Users\win\miniconda3\envs\venv1\lib\site-packages\dash\dash.py:1869, in Dash.enable_dev_tools(self, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors)
#    1867 if debug:
#    1868     if jupyter_dash.active:
# -> 1869         jupyter_dash.configure_callback_exception_handling(
#    1870             self, dev_tools.prune_errors
#    1871         )
#    1872     elif dev_tools.prune_errors:
#    1873         secret = gen_salt(20)
#
# File c:\Users\win\miniconda3\envs\venv1\lib\site-packages\dash\_jupyter.py:446, in JupyterDash.configure_callback_exception_handling(self, app, dev_tools_prune_errors)
#     443 def configure_callback_exception_handling(self, app, dev_tools_prune_errors):
#     444     """Install traceback handling for callbacks"""
# --> 446     @app.server.errorhandler(Exception)
#     447     def _wrap_errors(error):
#     448         # Compute number of stack frames to skip to get down to callback
#     449         skip = _get_skip(error) if dev_tools_prune_errors else 0
#     451         # Customized formatargvalues function we can place function parameters
#     452         # on separate lines
#
# File c:\Users\win\miniconda3\envs\venv1\lib\site-packages\flask\sansio\scaffold.py:46, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      45 def wrapper_func(self: Scaffold, *args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 46     self._check_setup_finished(f_name)
#      47     return f(self, *args, **kwargs)
#
# File c:\Users\win\miniconda3\envs\venv1\lib\site-packages\flask\sansio\app.py:415, in App._check_setup_finished(self, f_name)
#     413 def _check_setup_finished(self, f_name: str) -> None:
#     414     if self._got_first_request:
# --> 415         raise AssertionError(
#     416             f"The setup method '{f_name}' can no longer be called"
#     417             " on the application. It has already handled its first"
#     418             " request, any changes will not be applied"
#     419             " consistently.\n"
#     420             "Make sure all imports, decorators, functions, etc."
#     421             " needed to set up the application are done before"
#     422             " running it."
#     423         )
#
# AssertionError: The setup method 'errorhandler' can no longer be called on the application. It has already handled its first request, any changes will not be applied consistently.
# Make sure all imports, decorators, functions, etc. needed to set up the application are done before running it.
